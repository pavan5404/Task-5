# %%
# Import libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
df = pd.read_csv("C:/Users/DELL/OneDrive/Desktop/Students Social Media Addiction.csv")
print(df)
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
# Consider only the first 98 entries
df = df.head(98)
print(df)
# Out:
#     Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0            1   19  Female  Undergraduate  Bangladesh                    5.2
# 1            2   22    Male       Graduate       India                    2.1
# 2            3   20  Female  Undergraduate         USA                    6.0
# 3            4   18    Male    High School          UK                    3.0
# 4            5   21    Male       Graduate      Canada                    4.5
# ..         ...  ...     ...            ...         ...                    ...
# 93          94   20  Female    High School      Kosovo                    5.5
# 94          95   23    Male       Graduate      Bosnia                    2.4
# 95          96   19  Female  Undergraduate       Qatar                    4.9
# 96          97   18    Male    High School      Kuwait                    5.7
# 97          98   22  Female       Graduate     Bahrain                    2.8
#
# ...

# %%
# Basic Info
print("Data Info:")
print(df.info())
# Out:
# Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 98 entries, 0 to 97
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    98 non-null     int64
#  1   Age                           98 non-null     int64
#  2   Gender                        98 non-null     object
#  3   Academic_Level                98 non-null     object
#  4   Country                       98 non-null     object
#  5   Avg_Daily_Usage_Hours         98 non-null     float64
#  6   Most_Used_Platform            98 non-null     object
#  7   Affects_Academic_Performance  98 non-null     object
#  8   Sleep_Hours_Per_Night         98 non-null     float64
#  9   Mental_Health_Score           98 non-null     int64
#  10  Relationship_Status           98 non-null     object
#  11  Conflicts_Over_Social_Media   98 non-null     int64
# ...

# %%
# Summary Statistics
print("\nSummary Statistics:")
print(df.describe())
# Out:
# Summary Statistics:
#        Student_ID        Age  Avg_Daily_Usage_Hours  Sleep_Hours_Per_Night  \
# count   98.000000  98.000000              98.000000              98.000000
# mean    49.500000  20.336735               4.338776               6.172449
# std     28.434134   1.661845               1.281641               0.778418
# min      1.000000  18.000000               1.500000               4.500000
# 25%     25.250000  19.000000               3.200000               5.500000
# 50%     49.500000  20.000000               4.600000               5.900000
# 75%     73.750000  21.000000               5.500000               6.875000
# max     98.000000  24.000000               7.200000               8.000000
#
#        Mental_Health_Score  Conflicts_Over_Social_Media  Addicted_Score
# count            98.000000                    98.000000       98.000000
# mean              6.275510                     2.540816        6.387755
# ...

# %%
# Value Counts for categorical columns
for col in df.select_dtypes(include='object').columns:
    print(f"\nValue counts for {col}:\n", df[col].value_counts())
# Out:
# Value counts for Gender:
#  Gender
# Female    49
# Male      49
# Name: count, dtype: int64
#
# Value counts for Academic_Level:
#  Academic_Level
# Undergraduate    46
# Graduate         28
# High School      24
# Name: count, dtype: int64
#
# Value counts for Country:
#  Country
# Bangladesh    1
# Moldova       1
# Lithuania     1
# Latvia        1
# Estonia       1
#              ..
# Vietnam       1
# Thailand      1
# Malaysia      1
# Singapore     1
# Bahrain       1
# Name: count, Length: 98, dtype: int64
#
# Value counts for Most_Used_Platform:
#  Most_Used_Platform
# Instagram    23
# TikTok       23
# LinkedIn     18
# Facebook     13
# Snapchat     12
# YouTube       8
# Twitter       1
# Name: count, dtype: int64
#
# Value counts for Affects_Academic_Performance:
#  Affects_Academic_Performance
# Yes    58
# No     40
# Name: count, dtype: int64
#
# Value counts for Relationship_Status:
#  Relationship_Status
# Single             37
# In Relationship    32
# ...

# %%
# Pairplot
sns.pairplot(df)
plt.show()

# %%
# Correlation Heatmap (only numeric columns)
plt.figure(figsize=(10, 8))
sns.heatmap(df.select_dtypes(include='number').corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Histograms
df.hist(figsize=(12, 10), bins=20)
plt.suptitle('Histograms of Features')
plt.show()

# %%
# Boxplots
plt.figure(figsize=(12,8))
sns.boxplot(data=df)
plt.title('Boxplots of Numeric Features')
plt.xticks(rotation=45)
plt.show()

# %%
# Scatterplot Example
plt.figure(figsize=(6,4))
sns.scatterplot(x='Avg_Daily_Usage_Hours', y='Mental_Health_Score', data=df)
plt.title('Daily Uasge Hours vs Mental Health')
plt.show()
